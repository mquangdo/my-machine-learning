# %% [markdown]
# ## LDA with Iris dataset

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X, y = iris.data, iris.target

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 1], X[:, 3], c=y)
plt.grid(True)
plt.title('Original data')
# Out:
# Text(0.5, 1.0, 'Original data')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()
lda.fit(X, y)
# Out:
# LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import classification_report

y_pred = lda.predict(X)

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       0.98      0.96      0.97        50
#            2       0.96      0.98      0.97        50
#
#     accuracy                           0.98       150
#    macro avg       0.98      0.98      0.98       150
# weighted avg       0.98      0.98      0.98       150

# %%
lda.classes_
# Out:
# array([0, 1, 2])

# %%
lda.coef_
# Out:
# array([[  6.31475846,  12.13931718, -16.94642465, -20.77005459],
#        [ -1.53119919,  -4.37604348,   4.69566531,   3.06258539],
#        [ -4.78355927,  -7.7632737 ,  12.25075935,  17.7074692 ]])

# %% [markdown]
# ## Transform and Visualize

# %%
X_transformed = lda.transform(X)
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], c=y)
plt.grid(True)
plt.title('Transformed data')
# Out:
# Text(0.5, 1.0, 'Transformed data')

# %%
X_01 = X[(y == 0) | (y == 1)]
y_01 = y[(y == 0) | (y == 1)]

# %% [markdown]
# ## Two categories experiment

# %%
plt.scatter(X_01[:, 0], X_01[:, 1], c=y_01)

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_01, y_01)
# Out:
# LinearDiscriminantAnalysis()

# %%
X_01_transformed = lda.transform(X_01)
plt.scatter(X_01_transformed[:, 0], X_01_transformed[:, 1], c=y_01) #error because there is only 1 axis
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[107], line 2
#       1 X_01_transformed = lda.transform(X_01)
# ----> 2 plt.scatter(X_01_transformed[:, 0], X_01_transformed[:, 1], c=y_01)
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
import numpy as np

plt.scatter(X_01_transformed[:, 0], y =np.zeros(len(X_01_transformed)) , c=y_01) #error because there is only 1 axis
plt.grid(True)
