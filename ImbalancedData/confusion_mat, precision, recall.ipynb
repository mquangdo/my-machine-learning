# %%
import numpy as np
from imblearn.datasets import fetch_datasets

# %%
thyroid_sick = fetch_datasets()['thyroid_sick']

# %%
X, y = thyroid_sick.data, thyroid_sick.target

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (6, 6)

# %%
unique_elems, counts = np.unique(y, return_counts=True)

# %%
fig1, ax1 = plt.subplots()
ax1.pie(counts, labels = unique_elems, shadow=True, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x237554e8f80>,
# ...
#  [Text(-1.079704341293942, 0.21032958753113015, '-1'),
#   Text(1.0797043339092622, -0.21032962543958578, '1')],
#  [Text(-0.5889296407057865, 0.11472522956243461, '93.9%'),
#   Text(0.5889296366777793, -0.11472525023977405, '6.1%')])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
clf = LogisticRegression().fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report, accuracy_score, pair_confusion_matrix

print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.99      0.96      0.98      1084
#            1       0.51      0.88      0.64        48
#
#     accuracy                           0.96      1132
#    macro avg       0.75      0.92      0.81      1132
# weighted avg       0.97      0.96      0.96      1132

# %%
sns.heatmap(confusion_matrix(y_pred, y_test), annot=True,cbar=True)
# Out:
# <Axes: >
