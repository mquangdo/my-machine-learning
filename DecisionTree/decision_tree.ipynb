# %%
from sklearn.datasets import load_iris

data = load_iris()

# %%
X, y = data.data, data.target

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree

print(tree.export_text(clf))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: 0
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %%
import matplotlib.pyplot as plt 


plt.figure(figsize=(50,30))
tree.plot_tree(clf, feature_names=data.feature_names, class_names=data.target_names,filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(0.5769230769230769, 0.75, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(0.3076923076923077, 0.5833333333333334, 'petal length (cm) <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'petal width (cm) <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.46153846153846156, 0.4166666666666667, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
# ...

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16932\3257800236.py:5: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
X = data
y = [1 if price > 20 else 0 for price in target] # 1 nhà giá cao, 0 nhà giá thấp

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(max_depth=3)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
plt.figure(figsize=(50,30))
tree.plot_tree(tree_clf, feature_names=['crim', 'zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat'],class_names=['low','high' ],filled=True)
# Out:
# [Text(0.5, 0.875, 'lstat <= 14.115\ngini = 0.489\nsamples = 506\nvalue = [215, 291]\nclass = high'),
#  Text(0.25, 0.625, 'rm <= 6.034\ngini = 0.272\nsamples = 321\nvalue = [52, 269]\nclass = high'),
#  Text(0.125, 0.375, 'dis <= 4.714\ngini = 0.497\nsamples = 78\nvalue = [36, 42]\nclass = high'),
#  Text(0.0625, 0.125, 'gini = 0.435\nsamples = 50\nvalue = [16, 34]\nclass = high'),
#  Text(0.1875, 0.125, 'gini = 0.408\nsamples = 28\nvalue = [20, 8]\nclass = low'),
#  Text(0.375, 0.375, 'lstat <= 11.815\ngini = 0.123\nsamples = 243\nvalue = [16, 227]\nclass = high'),
#  Text(0.3125, 0.125, 'gini = 0.045\nsamples = 216\nvalue = [5, 211]\nclass = high'),
#  Text(0.4375, 0.125, 'gini = 0.483\nsamples = 27\nvalue = [11, 16]\nclass = high'),
#  Text(0.75, 0.625, 'tax <= 300.0\ngini = 0.21\nsamples = 185\nvalue = [163, 22]\nclass = low'),
#  Text(0.625, 0.375, 'age <= 94.55\ngini = 0.491\nsamples = 23\nvalue = [10.0, 13.0]\nclass = high'),
# ...

# %%
loves_popcorn = ['Yes','Yes','No','No','Yes','Yes','No']
loves_soda = ['Yes','No','Yes','Yes','Yes','No','No']
age = [7,12,18,35,38,50,83]
loves_coolasice = ['No','No','Yes','Yes','Yes','No','No']

df = pd.DataFrame({'Loves Popcorn': loves_popcorn, 'Loves Soda':loves_soda, 'Age':age})

# %%
df['Loves Popcorn'] = df['Loves Popcorn'].replace({'Yes':1, 'No':0}).astype('int')
df['Loves Soda'] = df['Loves Soda'].replace({'Yes':1, 'No':0}).astype('int')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16932\1125083063.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Loves Popcorn'] = df['Loves Popcorn'].replace({'Yes':1, 'No':0}).astype('int')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16932\1125083063.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Loves Soda'] = df['Loves Soda'].replace({'Yes':1, 'No':0}).astype('int')

# %%
df
# Out:
#    Loves Popcorn  Loves Soda  Age
# 0              1           1    7
# 1              1           0   12
# 2              0           1   18
# 3              0           1   35
# 4              1           1   38
# 5              1           0   50
# 6              0           0   83

# %%
X = df.values
y = loves_coolasice

# %%
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(tree_clf, feature_names=df.columns, class_names=['No', 'Yes'],filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'Loves Soda <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = No'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No'),
#  Text(0.6, 0.5, 'Age <= 12.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Yes')]
